# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
import pickle
from lightgbm import LGBMClassifier
from sklearn.ensemble import IsolationForest
from sklearn.metrics import f1_score, accuracy_score

# %%
data = pd.read_csv('Data/traintest_mod.csv')
data.head()
# Out:
#   trans_date_trans_time                            merchant       category  \
# 0   2019-01-01 00:00:18          fraud_Rippin, Kub and Mann       misc_net
# 1   2019-01-01 00:00:44     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2   2019-01-01 00:00:51                fraud_Lind-Buckridge  entertainment
# 3   2019-01-01 00:01:16  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   2019-01-01 00:03:06                 fraud_Keeling-Crist       misc_pos
#
#       amt      first     last gender state    zip      lat  ...         dob  \
# 0    4.97   Jennifer    Banks      F    NC  28654  36.0788  ...  1988-03-09
# 1  107.23  Stephanie     Gill      F    WA  99160  48.8878  ...  1978-06-21
# 2  220.11     Edward  Sanchez      M    ID  83252  42.1808  ...  1962-01-19
# 3   45.00     Jeremy    White      M    MT  59632  46.2306  ...  1967-01-12
# 4   41.96      Tyler   Garcia      M    VA  24433  38.4207  ...  1986-03-28
#
#    merch_lat  merch_long is_fraud  year  month  day  hour      DOW  generation
# 0  36.011293  -82.048315      0.0  2019      1    1     0  Tuesday         80s
# 1  49.159047 -118.186462      0.0  2019      1    1     0  Tuesday         70s
# 2  43.150704 -112.154481      0.0  2019      1    1     0  Tuesday         60s
# 3  47.034331 -112.561071      0.0  2019      1    1     0  Tuesday         60s
# 4  38.674999  -78.632459      0.0  2019      1    1     0  Tuesday         80s
#
# [5 rows x 23 columns]

# %%
data['full_name'] = data.apply(lambda x: x['first'] + ' ' + x['last'], axis = 1)
data.head()
# Out:
#   trans_date_trans_time                            merchant       category  \
# 0   2019-01-01 00:00:18          fraud_Rippin, Kub and Mann       misc_net
# 1   2019-01-01 00:00:44     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2   2019-01-01 00:00:51                fraud_Lind-Buckridge  entertainment
# 3   2019-01-01 00:01:16  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   2019-01-01 00:03:06                 fraud_Keeling-Crist       misc_pos
#
#       amt      first     last gender state    zip      lat  ...  merch_lat  \
# 0    4.97   Jennifer    Banks      F    NC  28654  36.0788  ...  36.011293
# 1  107.23  Stephanie     Gill      F    WA  99160  48.8878  ...  49.159047
# 2  220.11     Edward  Sanchez      M    ID  83252  42.1808  ...  43.150704
# 3   45.00     Jeremy    White      M    MT  59632  46.2306  ...  47.034331
# 4   41.96      Tyler   Garcia      M    VA  24433  38.4207  ...  38.674999
#
#    merch_long is_fraud  year  month  day  hour      DOW  generation  \
# 0  -82.048315      0.0  2019      1    1     0  Tuesday         80s
# 1 -118.186462      0.0  2019      1    1     0  Tuesday         70s
# 2 -112.154481      0.0  2019      1    1     0  Tuesday         60s
# 3 -112.561071      0.0  2019      1    1     0  Tuesday         60s
# 4  -78.632459      0.0  2019      1    1     0  Tuesday         80s
#
#         full_name
# 0  Jennifer Banks
# 1  Stephanie Gill
# 2  Edward Sanchez
# 3    Jeremy White
# 4    Tyler Garcia
#
# [5 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['trans_date_trans_time', 'merchant', 'category', 'amt', 'first', 'last',
#        'gender', 'state', 'zip', 'lat', 'long', 'city_pop', 'job', 'dob',
#        'merch_lat', 'merch_long', 'is_fraud', 'year', 'month', 'day', 'hour',
#        'DOW', 'generation', 'full_name'],
#       dtype='object')

# %%
cols_to_drop = ['trans_date_trans_time', 'first', 'last', 'dob']

data.drop(cols_to_drop, axis = 1, inplace = True)

# %%
data.head()
# Out:
#                              merchant       category     amt gender state  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97      F    NC
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23      F    WA
# 2                fraud_Lind-Buckridge  entertainment  220.11      M    ID
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00      M    MT
# 4                 fraud_Keeling-Crist       misc_pos   41.96      M    VA
#
#      zip      lat      long  city_pop                                job  \
# 0  28654  36.0788  -81.1781      3495          Psychologist, counselling
# 1  99160  48.8878 -118.2105       149  Special educational needs teacher
# 2  83252  42.1808 -112.2620      4154        Nature conservation officer
# 3  59632  46.2306 -112.1138      1939                    Patent attorney
# 4  24433  38.4207  -79.4629        99     Dance movement psychotherapist
#
#    merch_lat  merch_long  is_fraud  year  month  day  hour      DOW  \
# 0  36.011293  -82.048315       0.0  2019      1    1     0  Tuesday
# 1  49.159047 -118.186462       0.0  2019      1    1     0  Tuesday
# 2  43.150704 -112.154481       0.0  2019      1    1     0  Tuesday
# 3  47.034331 -112.561071       0.0  2019      1    1     0  Tuesday
# 4  38.674999  -78.632459       0.0  2019      1    1     0  Tuesday
#
#   generation       full_name
# 0        80s  Jennifer Banks
# 1        70s  Stephanie Gill
# 2        60s  Edward Sanchez
# 3        60s    Jeremy White
# 4        80s    Tyler Garcia

# %%
cols_to_encode = ['merchant', 'category', 'gender', 'state', 'job', 'merch_lat', 'merch_long',
                 'DOW', 'generation', 'full_name']

for col in cols_to_encode:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    
data.head()
# Out:
#    merchant  category     amt  gender  state    zip      lat      long  \
# 0       514         8    4.97       0     27  28654  36.0788  -81.1781
# 1       241         4  107.23       0     47  99160  48.8878 -118.2105
# 2       390         0  220.11       1     13  83252  42.1808 -112.2620
# 3       360         2   45.00       1     26  59632  46.2306 -112.1138
# 4       297         9   41.96       1     45  24433  38.4207  -79.4629
#
#    city_pop  job  merch_lat  merch_long  is_fraud  year  month  day  hour  \
# 0      3495  372     550600     1223201       0.0  2019      1    1     0
# 1       149  431    1745263      110910       0.0  2019      1    1     0
# 2      4154  308    1451077      169563       0.0  2019      1    1     0
# 3      1939  330    1697797      164676       0.0  2019      1    1     0
# 4        99  116     787219     1458121       0.0  2019      1    1     0
#
#    DOW  generation  full_name
# 0    5           7        423
# 1    5           6        884
# 2    5           5        304
# 3    5           5        442
# 4    5           7        950

# %%
data.tail()
# Out:
#          merchant  category     amt  gender  state    zip      lat      long  \
# 1852389       507         5   43.77       1     24  63453  40.4931  -91.8912
# 1852390       264         7  111.84       1     43  77566  29.0393  -95.4401
# 1852391       496         7   86.88       0     47  99323  46.1966 -118.9017
# 1852392        75        13    7.99       1     13  83643  44.6255 -116.4493
# 1852393       125         0   38.13       1     36  73034  35.6665  -97.4798
#
#          city_pop  job  merch_lat  merch_long  is_fraud  year  month  day  \
# 1852389       519  477     978166      715433       NaN  2020     12   31
# 1852390     28739  207      88053      495569       NaN  2020     12   31
# 1852391      3684  307    1686654       87693       NaN  2020     12   31
# 1852392       129   63    1571421      134541       NaN  2020     12   31
# 1852393    116001  289     565192      450378       NaN  2020     12   31
#
#          hour  DOW  generation  full_name
# 1852389    23    4           5        699
# 1852390    23    4           8        494
# 1852391    23    4           7         61
# 1852392    23    4           5        316
# 1852393    23    4           8        835

# %%
data['lat_diff'] = data['lat'] - data['merch_lat']
data['long_diff'] = data['long'] - data['merch_long']

a = (np.square(np.sin(np.divide(data['lat_diff'], 2)*np.pi/360)) + 
    np.multiply(np.multiply(np.cos(data['lat']*np.pi/360), np.cos(data['merch_lat']*np.pi/360)),
               np.square(np.sin(np.divide(data['long_diff'], 2))*np.pi/360)))
     
c = 2* np.arctan2(np.sqrt(a), np.sqrt(1-a))
     
data['km_dist'] = 6371*c
     
data['km_dist'].head()
# Out:
# 0    13125.216454
# 1     3664.300303
# 2    13054.758619
# 3      515.553928
# 4    12263.456275
# Name: km_dist, dtype: float64

# %%
data['km_dist'].sort_values()
# Out:
# 1020428        0.013611
# 1225432        1.101354
# 1382785        2.498619
# 1679408        3.505416
# 914208         4.205209
#                ...
# 1781152    20012.134829
# 975562     20012.447972
# 1735422    20012.488844
# 628815     20012.907285
# 1469655    20014.224438
# Name: km_dist, Length: 1852394, dtype: float64

# %%
train = data[data['is_fraud'].notnull()]
test = data[data['is_fraud'].isnull()]

X = train.drop(['is_fraud'], axis = 1)
y = train['is_fraud']

test.drop(['is_fraud'], axis = 1, inplace = True)
target = pd.read_csv('Data/fraudTest.csv')['is_fraud']
# Out:
# /home/aryan/.local/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size = 0.15, random_state = 0, stratify = y)

# %%
y_train.value_counts()
# Out:
# 0.0    1095793
# 1.0       6380
# Name: is_fraud, dtype: int64

# %%
weights = []
for i in y_train:
    if i == 0:
        weights.append(6380)
    elif i == 1:
        weights.append(1095793)

# %%
anomaly_model = IsolationForest(n_estimators = 200, n_jobs = -1, random_state = 0, verbose = 1)

anomaly_model.fit(x_train, y_train, sample_weight=weights)
val_pred = anomaly_model.predict(x_val)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done   2 out of  12 | elapsed:   10.4s remaining:   52.1s
# [Parallel(n_jobs=12)]: Done  12 out of  12 | elapsed:   11.0s finished

# %%
val_pred = pd.Series(val_pred).replace(1, 0)
val_pred = val_pred.replace(-1, 1)

# %%
val_pred.value_counts()
# Out:
# 0    117631
# 1     76871
# dtype: int64

# %%
print("Val F1-score: ", f1_score(y_val, val_pred))
# Out:
# Val F1-score:  0.02212905624575304

# %% [markdown]
# Well that experiment didn't work out so well
#
# Guess I'll just oversample and treat this as a classification problem

# %%
sm = SMOTE(random_state = 0)
x_train, y_train = sm.fit_resample(x_train, y_train)

y_train.shape
# Out:
# (2191586,)

# %%
lgb = LGBMClassifier(n_estimators = 8000, learning_rate = 0.1, max_depth = 14, num_leaves = 1024,
                     random_state = 0, n_jobs = -1, reg_lambda = 0.1)
lgb.fit(x_train, y_train, early_stopping_rounds = 200, eval_set = [(x_train, y_train), (x_val, y_val)],
       verbose = True)
# Out:
# [1]	training's binary_logloss: 0.613084	valid_1's binary_logloss: 0.613186
# Training until validation scores don't improve for 200 rounds
# [2]	training's binary_logloss: 0.547424	valid_1's binary_logloss: 0.547264
# [3]	training's binary_logloss: 0.492345	valid_1's binary_logloss: 0.491748
# [4]	training's binary_logloss: 0.446119	valid_1's binary_logloss: 0.445076
# [5]	training's binary_logloss: 0.406064	valid_1's binary_logloss: 0.404477
# [6]	training's binary_logloss: 0.371064	valid_1's binary_logloss: 0.368918
# [7]	training's binary_logloss: 0.340553	valid_1's binary_logloss: 0.33805
# [8]	training's binary_logloss: 0.31399	valid_1's binary_logloss: 0.311123
# [9]	training's binary_logloss: 0.290474	valid_1's binary_logloss: 0.28731
# [10]	training's binary_logloss: 0.269754	valid_1's binary_logloss: 0.266543
# [11]	training's binary_logloss: 0.25131	valid_1's binary_logloss: 0.247837
# [12]	training's binary_logloss: 0.234771	valid_1's binary_logloss: 0.231157
# [13]	training's binary_logloss: 0.219961	valid_1's binary_logloss: 0.216278
# [14]	training's binary_logloss: 0.206028	valid_1's binary_logloss: 0.20234
# [15]	training's binary_logloss: 0.193985	valid_1's binary_logloss: 0.190453
# [16]	training's binary_logloss: 0.183582	valid_1's binary_logloss: 0.180098
# [17]	training's binary_logloss: 0.173749	valid_1's binary_logloss: 0.170502
# [18]	training's binary_logloss: 0.165219	valid_1's binary_logloss: 0.161921
# [19]	training's binary_logloss: 0.15634	valid_1's binary_logloss: 0.153314
# [20]	training's binary_logloss: 0.148595	valid_1's binary_logloss: 0.145694
# [21]	training's binary_logloss: 0.142186	valid_1's binary_logloss: 0.139427
# [22]	training's binary_logloss: 0.135409	valid_1's binary_logloss: 0.132889
# [23]	training's binary_logloss: 0.129523	valid_1's binary_logloss: 0.127248
# [24]	training's binary_logloss: 0.124585	valid_1's binary_logloss: 0.122495
# [25]	training's binary_logloss: 0.11981	valid_1's binary_logloss: 0.117906
# [26]	training's binary_logloss: 0.115493	valid_1's binary_logloss: 0.113862
# [27]	training's binary_logloss: 0.10997	valid_1's binary_logloss: 0.108891
# [28]	training's binary_logloss: 0.106148	valid_1's binary_logloss: 0.10522
# [29]	training's binary_logloss: 0.102792	valid_1's binary_logloss: 0.102103
# [30]	training's binary_logloss: 0.0996106	valid_1's binary_logloss: 0.0991455
# [31]	training's binary_logloss: 0.0967549	valid_1's binary_logloss: 0.0965471
# [32]	training's binary_logloss: 0.0933749	valid_1's binary_logloss: 0.0935065
# [33]	training's binary_logloss: 0.0905245	valid_1's binary_logloss: 0.0907903
# [34]	training's binary_logloss: 0.0874355	valid_1's binary_logloss: 0.0879539
# [35]	training's binary_logloss: 0.083845	valid_1's binary_logloss: 0.0847726
# [36]	training's binary_logloss: 0.0817231	valid_1's binary_logloss: 0.0827779
# [37]	training's binary_logloss: 0.0786394	valid_1's binary_logloss: 0.0800933
# [38]	training's binary_logloss: 0.0764017	valid_1's binary_logloss: 0.0781684
# [39]	training's binary_logloss: 0.0746035	valid_1's binary_logloss: 0.0765491
# [40]	training's binary_logloss: 0.0713762	valid_1's binary_logloss: 0.073762
# [41]	training's binary_logloss: 0.0694738	valid_1's binary_logloss: 0.0721028
# [42]	training's binary_logloss: 0.0679664	valid_1's binary_logloss: 0.0707777
# [43]	training's binary_logloss: 0.0658099	valid_1's binary_logloss: 0.0688818
# [44]	training's binary_logloss: 0.0640553	valid_1's binary_logloss: 0.0672617
# [45]	training's binary_logloss: 0.062466	valid_1's binary_logloss: 0.0658598
# [46]	training's binary_logloss: 0.0608598	valid_1's binary_logloss: 0.0644594
# [47]	training's binary_logloss: 0.0587971	valid_1's binary_logloss: 0.0626687
# [48]	training's binary_logloss: 0.0577265	valid_1's binary_logloss: 0.0616414
# [49]	training's binary_logloss: 0.0564369	valid_1's binary_logloss: 0.0603702
# [50]	training's binary_logloss: 0.0552908	valid_1's binary_logloss: 0.0594002
# [51]	training's binary_logloss: 0.0542266	valid_1's binary_logloss: 0.0584277
# [52]	training's binary_logloss: 0.0531139	valid_1's binary_logloss: 0.0573978
# [53]	training's binary_logloss: 0.0511084	valid_1's binary_logloss: 0.0555807
# [54]	training's binary_logloss: 0.0494783	valid_1's binary_logloss: 0.0542044
# [55]	training's binary_logloss: 0.0485515	valid_1's binary_logloss: 0.0533872
# [56]	training's binary_logloss: 0.0478409	valid_1's binary_logloss: 0.0526682
# [57]	training's binary_logloss: 0.0467366	valid_1's binary_logloss: 0.0517078
# [58]	training's binary_logloss: 0.0459198	valid_1's binary_logloss: 0.0509747
# [59]	training's binary_logloss: 0.0445594	valid_1's binary_logloss: 0.049803
# [60]	training's binary_logloss: 0.0426661	valid_1's binary_logloss: 0.0482257
# [61]	training's binary_logloss: 0.0415677	valid_1's binary_logloss: 0.0472629
# [62]	training's binary_logloss: 0.040697	valid_1's binary_logloss: 0.0464783
# [63]	training's binary_logloss: 0.0399838	valid_1's binary_logloss: 0.0458536
# [64]	training's binary_logloss: 0.0389254	valid_1's binary_logloss: 0.0448656
# [65]	training's binary_logloss: 0.0380221	valid_1's binary_logloss: 0.0440385
# [66]	training's binary_logloss: 0.0369427	valid_1's binary_logloss: 0.0431397
# [67]	training's binary_logloss: 0.0357524	valid_1's binary_logloss: 0.0420249
# [68]	training's binary_logloss: 0.034527	valid_1's binary_logloss: 0.0409042
# [69]	training's binary_logloss: 0.0331791	valid_1's binary_logloss: 0.0396661
# [70]	training's binary_logloss: 0.0325456	valid_1's binary_logloss: 0.0390492
# [71]	training's binary_logloss: 0.0306528	valid_1's binary_logloss: 0.0371917
# [72]	training's binary_logloss: 0.0297358	valid_1's binary_logloss: 0.0362742
# [73]	training's binary_logloss: 0.0285701	valid_1's binary_logloss: 0.0351697
# [74]	training's binary_logloss: 0.027429	valid_1's binary_logloss: 0.0340566
# [75]	training's binary_logloss: 0.0268999	valid_1's binary_logloss: 0.0335601
# [76]	training's binary_logloss: 0.0260912	valid_1's binary_logloss: 0.0327766
# [77]	training's binary_logloss: 0.0246889	valid_1's binary_logloss: 0.0313591
# [78]	training's binary_logloss: 0.023811	valid_1's binary_logloss: 0.0304694
# [79]	training's binary_logloss: 0.0230324	valid_1's binary_logloss: 0.0296571
# [80]	training's binary_logloss: 0.0223484	valid_1's binary_logloss: 0.0289964
# [81]	training's binary_logloss: 0.021785	valid_1's binary_logloss: 0.0284104
# [82]	training's binary_logloss: 0.0206514	valid_1's binary_logloss: 0.0272258
# [83]	training's binary_logloss: 0.0199452	valid_1's binary_logloss: 0.02648
# [84]	training's binary_logloss: 0.0194707	valid_1's binary_logloss: 0.0260321
# [85]	training's binary_logloss: 0.0185246	valid_1's binary_logloss: 0.0250274
# [86]	training's binary_logloss: 0.017561	valid_1's binary_logloss: 0.0240001
# [87]	training's binary_logloss: 0.0167572	valid_1's binary_logloss: 0.0231375
# [88]	training's binary_logloss: 0.0163417	valid_1's binary_logloss: 0.0226844
# [89]	training's binary_logloss: 0.0157908	valid_1's binary_logloss: 0.0221155
# [90]	training's binary_logloss: 0.0151387	valid_1's binary_logloss: 0.0213981
# [91]	training's binary_logloss: 0.014669	valid_1's binary_logloss: 0.0209139
# [92]	training's binary_logloss: 0.0141849	valid_1's binary_logloss: 0.0203944
# [93]	training's binary_logloss: 0.0138551	valid_1's binary_logloss: 0.020046
# [94]	training's binary_logloss: 0.0130754	valid_1's binary_logloss: 0.0191668
# [95]	training's binary_logloss: 0.0124238	valid_1's binary_logloss: 0.018475
# [96]	training's binary_logloss: 0.0121539	valid_1's binary_logloss: 0.0182014
# [97]	training's binary_logloss: 0.0116891	valid_1's binary_logloss: 0.0176824
# [98]	training's binary_logloss: 0.0112724	valid_1's binary_logloss: 0.0172505
# [99]	training's binary_logloss: 0.0109745	valid_1's binary_logloss: 0.0169858
# [100]	training's binary_logloss: 0.0106379	valid_1's binary_logloss: 0.0166076
# [101]	training's binary_logloss: 0.0104318	valid_1's binary_logloss: 0.0163767
# [102]	training's binary_logloss: 0.010129	valid_1's binary_logloss: 0.0160948
# [103]	training's binary_logloss: 0.00981936	valid_1's binary_logloss: 0.0157734
# [104]	training's binary_logloss: 0.00956381	valid_1's binary_logloss: 0.015546
# [105]	training's binary_logloss: 0.00913563	valid_1's binary_logloss: 0.0150762
# [106]	training's binary_logloss: 0.00870393	valid_1's binary_logloss: 0.0145892
# [107]	training's binary_logloss: 0.0083042	valid_1's binary_logloss: 0.0141435
# [108]	training's binary_logloss: 0.00793671	valid_1's binary_logloss: 0.013715
# [109]	training's binary_logloss: 0.00771981	valid_1's binary_logloss: 0.0135087
# [110]	training's binary_logloss: 0.00740972	valid_1's binary_logloss: 0.013135
# [111]	training's binary_logloss: 0.00720353	valid_1's binary_logloss: 0.0129557
# [112]	training's binary_logloss: 0.0070567	valid_1's binary_logloss: 0.0128123
# [113]	training's binary_logloss: 0.00683576	valid_1's binary_logloss: 0.0125665
# [114]	training's binary_logloss: 0.00659441	valid_1's binary_logloss: 0.0122775
# [115]	training's binary_logloss: 0.00634408	valid_1's binary_logloss: 0.0120007
# [116]	training's binary_logloss: 0.0062299	valid_1's binary_logloss: 0.0118763
# [117]	training's binary_logloss: 0.00603974	valid_1's binary_logloss: 0.0117032
# [118]	training's binary_logloss: 0.00592423	valid_1's binary_logloss: 0.011563
# [119]	training's binary_logloss: 0.00571012	valid_1's binary_logloss: 0.0113074
# [120]	training's binary_logloss: 0.00559746	valid_1's binary_logloss: 0.0112216
# [121]	training's binary_logloss: 0.00545121	valid_1's binary_logloss: 0.0110999
# [122]	training's binary_logloss: 0.00524898	valid_1's binary_logloss: 0.0108488
# [123]	training's binary_logloss: 0.0051081	valid_1's binary_logloss: 0.0107152
# [124]	training's binary_logloss: 0.00498324	valid_1's binary_logloss: 0.0105555
# [125]	training's binary_logloss: 0.00486398	valid_1's binary_logloss: 0.0104535
# [126]	training's binary_logloss: 0.00475921	valid_1's binary_logloss: 0.0103279
# [127]	training's binary_logloss: 0.00464691	valid_1's binary_logloss: 0.0102389
# [128]	training's binary_logloss: 0.00446578	valid_1's binary_logloss: 0.010019
# [129]	training's binary_logloss: 0.0043754	valid_1's binary_logloss: 0.00994538
# [130]	training's binary_logloss: 0.00425002	valid_1's binary_logloss: 0.00978221
# [131]	training's binary_logloss: 0.00406196	valid_1's binary_logloss: 0.00953013
# [132]	training's binary_logloss: 0.00399845	valid_1's binary_logloss: 0.00950209
# [133]	training's binary_logloss: 0.0038887	valid_1's binary_logloss: 0.00936909
# [134]	training's binary_logloss: 0.00382788	valid_1's binary_logloss: 0.00932694
# [135]	training's binary_logloss: 0.00373802	valid_1's binary_logloss: 0.00925593
# [136]	training's binary_logloss: 0.00365998	valid_1's binary_logloss: 0.00917766
# [137]	training's binary_logloss: 0.00350259	valid_1's binary_logloss: 0.00895684
# [138]	training's binary_logloss: 0.00340264	valid_1's binary_logloss: 0.00887049
# [139]	training's binary_logloss: 0.00331351	valid_1's binary_logloss: 0.00878681
# [140]	training's binary_logloss: 0.00326942	valid_1's binary_logloss: 0.0087241
# [141]	training's binary_logloss: 0.00319081	valid_1's binary_logloss: 0.00866689
# [142]	training's binary_logloss: 0.00313967	valid_1's binary_logloss: 0.00862745
# [143]	training's binary_logloss: 0.00303241	valid_1's binary_logloss: 0.00849541
# [144]	training's binary_logloss: 0.00295418	valid_1's binary_logloss: 0.00843953
# [145]	training's binary_logloss: 0.00285254	valid_1's binary_logloss: 0.00829558
# [146]	training's binary_logloss: 0.00279903	valid_1's binary_logloss: 0.00825136
# [147]	training's binary_logloss: 0.0026947	valid_1's binary_logloss: 0.00816002
# [148]	training's binary_logloss: 0.00258924	valid_1's binary_logloss: 0.00802572
# [149]	training's binary_logloss: 0.00254928	valid_1's binary_logloss: 0.0079844
# [150]	training's binary_logloss: 0.00249513	valid_1's binary_logloss: 0.00791489
# [151]	training's binary_logloss: 0.00245861	valid_1's binary_logloss: 0.0078868
# [152]	training's binary_logloss: 0.0024021	valid_1's binary_logloss: 0.00783664
# [153]	training's binary_logloss: 0.00232085	valid_1's binary_logloss: 0.007729
# [154]	training's binary_logloss: 0.00224488	valid_1's binary_logloss: 0.00762661
# [155]	training's binary_logloss: 0.00215456	valid_1's binary_logloss: 0.00749429
# [156]	training's binary_logloss: 0.00211413	valid_1's binary_logloss: 0.00747149
# [157]	training's binary_logloss: 0.00205413	valid_1's binary_logloss: 0.00743142
# [158]	training's binary_logloss: 0.00200084	valid_1's binary_logloss: 0.00735708
# [159]	training's binary_logloss: 0.00196552	valid_1's binary_logloss: 0.00734186
# [160]	training's binary_logloss: 0.00190915	valid_1's binary_logloss: 0.00725492
# [161]	training's binary_logloss: 0.0018559	valid_1's binary_logloss: 0.0072056
# [162]	training's binary_logloss: 0.00180347	valid_1's binary_logloss: 0.00713752
# [163]	training's binary_logloss: 0.00175585	valid_1's binary_logloss: 0.00709516
# [164]	training's binary_logloss: 0.00169838	valid_1's binary_logloss: 0.00701531
# [165]	training's binary_logloss: 0.00166082	valid_1's binary_logloss: 0.00696319
# [166]	training's binary_logloss: 0.0015962	valid_1's binary_logloss: 0.00686878
# [167]	training's binary_logloss: 0.00156105	valid_1's binary_logloss: 0.00685231
# [168]	training's binary_logloss: 0.00153406	valid_1's binary_logloss: 0.00683235
# [169]	training's binary_logloss: 0.0014775	valid_1's binary_logloss: 0.00674328
# [170]	training's binary_logloss: 0.00145305	valid_1's binary_logloss: 0.00672425
# [171]	training's binary_logloss: 0.00142533	valid_1's binary_logloss: 0.00670109
# [172]	training's binary_logloss: 0.0013834	valid_1's binary_logloss: 0.00663776
# [173]	training's binary_logloss: 0.00136129	valid_1's binary_logloss: 0.00662915
# [174]	training's binary_logloss: 0.00132323	valid_1's binary_logloss: 0.00656696
# [175]	training's binary_logloss: 0.00129891	valid_1's binary_logloss: 0.00654954
# [176]	training's binary_logloss: 0.00127658	valid_1's binary_logloss: 0.00652846
# [177]	training's binary_logloss: 0.00125277	valid_1's binary_logloss: 0.00650369
# [178]	training's binary_logloss: 0.00122479	valid_1's binary_logloss: 0.00646841
# [179]	training's binary_logloss: 0.00119124	valid_1's binary_logloss: 0.0064091
# [180]	training's binary_logloss: 0.00114896	valid_1's binary_logloss: 0.00633565
# [181]	training's binary_logloss: 0.00111791	valid_1's binary_logloss: 0.0063085
# [182]	training's binary_logloss: 0.00109779	valid_1's binary_logloss: 0.00630122
# [183]	training's binary_logloss: 0.00106928	valid_1's binary_logloss: 0.00624996
# [184]	training's binary_logloss: 0.00103738	valid_1's binary_logloss: 0.00621417
# [185]	training's binary_logloss: 0.00101078	valid_1's binary_logloss: 0.00618021
# [186]	training's binary_logloss: 0.000991542	valid_1's binary_logloss: 0.00616961
# [187]	training's binary_logloss: 0.000959905	valid_1's binary_logloss: 0.00612061
# [188]	training's binary_logloss: 0.000934505	valid_1's binary_logloss: 0.00607561
# [189]	training's binary_logloss: 0.00091814	valid_1's binary_logloss: 0.00607951
# [190]	training's binary_logloss: 0.000896449	valid_1's binary_logloss: 0.00603758
# [191]	training's binary_logloss: 0.000866767	valid_1's binary_logloss: 0.00601903
# [192]	training's binary_logloss: 0.000852225	valid_1's binary_logloss: 0.00598711
# [193]	training's binary_logloss: 0.000829692	valid_1's binary_logloss: 0.0059772
# [194]	training's binary_logloss: 0.000808402	valid_1's binary_logloss: 0.00593607
# [195]	training's binary_logloss: 0.00078673	valid_1's binary_logloss: 0.00591242
# [196]	training's binary_logloss: 0.000772654	valid_1's binary_logloss: 0.00589494
# [197]	training's binary_logloss: 0.000759531	valid_1's binary_logloss: 0.00588772
# [198]	training's binary_logloss: 0.000746592	valid_1's binary_logloss: 0.00586737
# [199]	training's binary_logloss: 0.000723292	valid_1's binary_logloss: 0.00581333
# [200]	training's binary_logloss: 0.000709791	valid_1's binary_logloss: 0.00579332
# [201]	training's binary_logloss: 0.000695461	valid_1's binary_logloss: 0.00578826
# [202]	training's binary_logloss: 0.000686351	valid_1's binary_logloss: 0.00578899
# [203]	training's binary_logloss: 0.000676433	valid_1's binary_logloss: 0.00577474
# [204]	training's binary_logloss: 0.000660398	valid_1's binary_logloss: 0.00573552
# [205]	training's binary_logloss: 0.000644911	valid_1's binary_logloss: 0.00572394
# [206]	training's binary_logloss: 0.000622264	valid_1's binary_logloss: 0.00568235
# [207]	training's binary_logloss: 0.000610996	valid_1's binary_logloss: 0.0056839
# [208]	training's binary_logloss: 0.00059572	valid_1's binary_logloss: 0.00565045
# [209]	training's binary_logloss: 0.000579511	valid_1's binary_logloss: 0.00560195
# [210]	training's binary_logloss: 0.000568179	valid_1's binary_logloss: 0.00560812
# [211]	training's binary_logloss: 0.000553993	valid_1's binary_logloss: 0.00558397
# [212]	training's binary_logloss: 0.000539179	valid_1's binary_logloss: 0.00557876
# [213]	training's binary_logloss: 0.000527035	valid_1's binary_logloss: 0.00556619
# [214]	training's binary_logloss: 0.000515595	valid_1's binary_logloss: 0.00557008
# [215]	training's binary_logloss: 0.000500588	valid_1's binary_logloss: 0.00554559
# [216]	training's binary_logloss: 0.000490103	valid_1's binary_logloss: 0.00553069
# [217]	training's binary_logloss: 0.000478941	valid_1's binary_logloss: 0.00552453
# [218]	training's binary_logloss: 0.000469847	valid_1's binary_logloss: 0.00550141
# [219]	training's binary_logloss: 0.000461183	valid_1's binary_logloss: 0.00547195
# [220]	training's binary_logloss: 0.000450739	valid_1's binary_logloss: 0.00547969
# [221]	training's binary_logloss: 0.000441446	valid_1's binary_logloss: 0.00545113
# [222]	training's binary_logloss: 0.000433232	valid_1's binary_logloss: 0.00544083
# [223]	training's binary_logloss: 0.000425775	valid_1's binary_logloss: 0.00542537
# [224]	training's binary_logloss: 0.000420219	valid_1's binary_logloss: 0.00543074
# [225]	training's binary_logloss: 0.000411195	valid_1's binary_logloss: 0.00540829
# [226]	training's binary_logloss: 0.000402746	valid_1's binary_logloss: 0.0053991
# [227]	training's binary_logloss: 0.000389256	valid_1's binary_logloss: 0.00535821
# [228]	training's binary_logloss: 0.000377881	valid_1's binary_logloss: 0.00535675
# [229]	training's binary_logloss: 0.000370175	valid_1's binary_logloss: 0.00536021
# [230]	training's binary_logloss: 0.000361662	valid_1's binary_logloss: 0.00535218
# [231]	training's binary_logloss: 0.000351729	valid_1's binary_logloss: 0.00533778
# [232]	training's binary_logloss: 0.000346933	valid_1's binary_logloss: 0.00534714
# [233]	training's binary_logloss: 0.000339315	valid_1's binary_logloss: 0.00533482
# [234]	training's binary_logloss: 0.0003303	valid_1's binary_logloss: 0.00533822
# [235]	training's binary_logloss: 0.000324626	valid_1's binary_logloss: 0.00533933
# [236]	training's binary_logloss: 0.000320203	valid_1's binary_logloss: 0.00534324
# [237]	training's binary_logloss: 0.000315807	valid_1's binary_logloss: 0.00532147
# [238]	training's binary_logloss: 0.000310912	valid_1's binary_logloss: 0.00532891
# [239]	training's binary_logloss: 0.000305579	valid_1's binary_logloss: 0.00532388
# [240]	training's binary_logloss: 0.00029974	valid_1's binary_logloss: 0.00531315
# [241]	training's binary_logloss: 0.000293992	valid_1's binary_logloss: 0.00531688
# [242]	training's binary_logloss: 0.000284973	valid_1's binary_logloss: 0.00529517
# [243]	training's binary_logloss: 0.000281134	valid_1's binary_logloss: 0.00528875
# [244]	training's binary_logloss: 0.000276064	valid_1's binary_logloss: 0.00527439
# [245]	training's binary_logloss: 0.000270672	valid_1's binary_logloss: 0.00526692
# [246]	training's binary_logloss: 0.000264121	valid_1's binary_logloss: 0.00525928
# [247]	training's binary_logloss: 0.000257121	valid_1's binary_logloss: 0.00525427
# [248]	training's binary_logloss: 0.00025181	valid_1's binary_logloss: 0.00525834
# [249]	training's binary_logloss: 0.000247274	valid_1's binary_logloss: 0.00526678
# [250]	training's binary_logloss: 0.00024103	valid_1's binary_logloss: 0.005246
# [251]	training's binary_logloss: 0.000237333	valid_1's binary_logloss: 0.00524298
# [252]	training's binary_logloss: 0.000232422	valid_1's binary_logloss: 0.00522647
# [253]	training's binary_logloss: 0.000228106	valid_1's binary_logloss: 0.00522405
# [254]	training's binary_logloss: 0.000221324	valid_1's binary_logloss: 0.00520577
# [255]	training's binary_logloss: 0.000217348	valid_1's binary_logloss: 0.00521462
# [256]	training's binary_logloss: 0.000213634	valid_1's binary_logloss: 0.00521951
# [257]	training's binary_logloss: 0.000209918	valid_1's binary_logloss: 0.00521575
# [258]	training's binary_logloss: 0.000202832	valid_1's binary_logloss: 0.0051848
# [259]	training's binary_logloss: 0.000197824	valid_1's binary_logloss: 0.00519137
# [260]	training's binary_logloss: 0.000194001	valid_1's binary_logloss: 0.00518711
# [261]	training's binary_logloss: 0.000190796	valid_1's binary_logloss: 0.00517014
# [262]	training's binary_logloss: 0.000186574	valid_1's binary_logloss: 0.00517484
# [263]	training's binary_logloss: 0.000183565	valid_1's binary_logloss: 0.00515579
# [264]	training's binary_logloss: 0.000181032	valid_1's binary_logloss: 0.00516
# [265]	training's binary_logloss: 0.000177455	valid_1's binary_logloss: 0.00514171
# [266]	training's binary_logloss: 0.000174833	valid_1's binary_logloss: 0.00514815
# [267]	training's binary_logloss: 0.000172084	valid_1's binary_logloss: 0.00514909
# [268]	training's binary_logloss: 0.00016851	valid_1's binary_logloss: 0.00515715
# [269]	training's binary_logloss: 0.000165692	valid_1's binary_logloss: 0.00515325
# [270]	training's binary_logloss: 0.000162966	valid_1's binary_logloss: 0.00515931
# [271]	training's binary_logloss: 0.000160038	valid_1's binary_logloss: 0.00514207
# [272]	training's binary_logloss: 0.000157466	valid_1's binary_logloss: 0.00514688
# [273]	training's binary_logloss: 0.000154826	valid_1's binary_logloss: 0.00514402
# [274]	training's binary_logloss: 0.000153269	valid_1's binary_logloss: 0.00514742
# [275]	training's binary_logloss: 0.000150237	valid_1's binary_logloss: 0.00512613
# [276]	training's binary_logloss: 0.000147485	valid_1's binary_logloss: 0.00513821
# [277]	training's binary_logloss: 0.000144835	valid_1's binary_logloss: 0.00513556
# [278]	training's binary_logloss: 0.000142125	valid_1's binary_logloss: 0.00512357
# [279]	training's binary_logloss: 0.00013998	valid_1's binary_logloss: 0.00512984
# [280]	training's binary_logloss: 0.000137476	valid_1's binary_logloss: 0.00513179
# [281]	training's binary_logloss: 0.000135432	valid_1's binary_logloss: 0.00513557
# [282]	training's binary_logloss: 0.000132499	valid_1's binary_logloss: 0.00512106
# [283]	training's binary_logloss: 0.000130204	valid_1's binary_logloss: 0.00510718
# [284]	training's binary_logloss: 0.000127792	valid_1's binary_logloss: 0.00511034
# [285]	training's binary_logloss: 0.000125868	valid_1's binary_logloss: 0.00511718
# [286]	training's binary_logloss: 0.000123933	valid_1's binary_logloss: 0.0051129
# [287]	training's binary_logloss: 0.00012236	valid_1's binary_logloss: 0.00512317
# [288]	training's binary_logloss: 0.000120282	valid_1's binary_logloss: 0.00513095
# [289]	training's binary_logloss: 0.000118447	valid_1's binary_logloss: 0.00512557
# [290]	training's binary_logloss: 0.000117529	valid_1's binary_logloss: 0.00513273
# [291]	training's binary_logloss: 0.000115651	valid_1's binary_logloss: 0.00512381
# [292]	training's binary_logloss: 0.000113368	valid_1's binary_logloss: 0.0051368
# [293]	training's binary_logloss: 0.000111446	valid_1's binary_logloss: 0.00513723
# [294]	training's binary_logloss: 0.000109841	valid_1's binary_logloss: 0.00514713
# [295]	training's binary_logloss: 0.000108221	valid_1's binary_logloss: 0.00516186
# [296]	training's binary_logloss: 0.000106682	valid_1's binary_logloss: 0.00515958
# [297]	training's binary_logloss: 0.000103693	valid_1's binary_logloss: 0.00514307
# [298]	training's binary_logloss: 0.000102784	valid_1's binary_logloss: 0.00515129
# [299]	training's binary_logloss: 0.000101217	valid_1's binary_logloss: 0.00515483
# [300]	training's binary_logloss: 9.98433e-05	valid_1's binary_logloss: 0.00516227
# [301]	training's binary_logloss: 9.72254e-05	valid_1's binary_logloss: 0.00514717
# [302]	training's binary_logloss: 9.59986e-05	valid_1's binary_logloss: 0.00515078
# [303]	training's binary_logloss: 9.3988e-05	valid_1's binary_logloss: 0.0051574
# [304]	training's binary_logloss: 9.25122e-05	valid_1's binary_logloss: 0.00515328
# [305]	training's binary_logloss: 9.12038e-05	valid_1's binary_logloss: 0.00515485
# [306]	training's binary_logloss: 8.91768e-05	valid_1's binary_logloss: 0.00515071
# [307]	training's binary_logloss: 8.79882e-05	valid_1's binary_logloss: 0.00515837
# [308]	training's binary_logloss: 8.60717e-05	valid_1's binary_logloss: 0.00513979
# [309]	training's binary_logloss: 8.43955e-05	valid_1's binary_logloss: 0.00514904
# [310]	training's binary_logloss: 8.33855e-05	valid_1's binary_logloss: 0.00514947
# [311]	training's binary_logloss: 8.21703e-05	valid_1's binary_logloss: 0.00515243
# [312]	training's binary_logloss: 8.09694e-05	valid_1's binary_logloss: 0.00515022
# [313]	training's binary_logloss: 7.91686e-05	valid_1's binary_logloss: 0.00513903
# [314]	training's binary_logloss: 7.80709e-05	valid_1's binary_logloss: 0.00514587
# [315]	training's binary_logloss: 7.73231e-05	valid_1's binary_logloss: 0.0051483
# [316]	training's binary_logloss: 7.63426e-05	valid_1's binary_logloss: 0.00514729
# [317]	training's binary_logloss: 7.55978e-05	valid_1's binary_logloss: 0.00515585
# [318]	training's binary_logloss: 7.47557e-05	valid_1's binary_logloss: 0.00515807
# [319]	training's binary_logloss: 7.36681e-05	valid_1's binary_logloss: 0.00515846
# [320]	training's binary_logloss: 7.17513e-05	valid_1's binary_logloss: 0.00514037
# [321]	training's binary_logloss: 7.03745e-05	valid_1's binary_logloss: 0.00515299
# [322]	training's binary_logloss: 6.86262e-05	valid_1's binary_logloss: 0.0051398
# [323]	training's binary_logloss: 6.78525e-05	valid_1's binary_logloss: 0.00514186
# [324]	training's binary_logloss: 6.6875e-05	valid_1's binary_logloss: 0.0051541
# [325]	training's binary_logloss: 6.58591e-05	valid_1's binary_logloss: 0.00516541
# [326]	training's binary_logloss: 6.51062e-05	valid_1's binary_logloss: 0.00516586
# [327]	training's binary_logloss: 6.44255e-05	valid_1's binary_logloss: 0.0051729
# [328]	training's binary_logloss: 6.37525e-05	valid_1's binary_logloss: 0.0051785
# [329]	training's binary_logloss: 6.28717e-05	valid_1's binary_logloss: 0.00516506
# [330]	training's binary_logloss: 6.17281e-05	valid_1's binary_logloss: 0.00516478
# [331]	training's binary_logloss: 6.07973e-05	valid_1's binary_logloss: 0.00517124
# [332]	training's binary_logloss: 6.00456e-05	valid_1's binary_logloss: 0.00516282
# [333]	training's binary_logloss: 5.87564e-05	valid_1's binary_logloss: 0.00514675
# [334]	training's binary_logloss: 5.76621e-05	valid_1's binary_logloss: 0.005133
# [335]	training's binary_logloss: 5.68752e-05	valid_1's binary_logloss: 0.0051433
# [336]	training's binary_logloss: 5.6309e-05	valid_1's binary_logloss: 0.0051464
# [337]	training's binary_logloss: 5.56212e-05	valid_1's binary_logloss: 0.0051493
# [338]	training's binary_logloss: 5.47544e-05	valid_1's binary_logloss: 0.00514501
# [339]	training's binary_logloss: 5.36149e-05	valid_1's binary_logloss: 0.00514418
# [340]	training's binary_logloss: 5.24885e-05	valid_1's binary_logloss: 0.00513982
# [341]	training's binary_logloss: 5.19338e-05	valid_1's binary_logloss: 0.00514061
# [342]	training's binary_logloss: 5.13236e-05	valid_1's binary_logloss: 0.0051468
# [343]	training's binary_logloss: 5.08243e-05	valid_1's binary_logloss: 0.00515447
# [344]	training's binary_logloss: 5.02056e-05	valid_1's binary_logloss: 0.00514968
# [345]	training's binary_logloss: 4.95864e-05	valid_1's binary_logloss: 0.00514526
# [346]	training's binary_logloss: 4.91721e-05	valid_1's binary_logloss: 0.00515499
# [347]	training's binary_logloss: 4.84172e-05	valid_1's binary_logloss: 0.00515014
# [348]	training's binary_logloss: 4.77843e-05	valid_1's binary_logloss: 0.0051549
# [349]	training's binary_logloss: 4.70762e-05	valid_1's binary_logloss: 0.00515056
# [350]	training's binary_logloss: 4.6439e-05	valid_1's binary_logloss: 0.00514946
# [351]	training's binary_logloss: 4.59409e-05	valid_1's binary_logloss: 0.0051478
# [352]	training's binary_logloss: 4.53973e-05	valid_1's binary_logloss: 0.00515071
# [353]	training's binary_logloss: 4.49769e-05	valid_1's binary_logloss: 0.0051578
# [354]	training's binary_logloss: 4.45298e-05	valid_1's binary_logloss: 0.00515214
# [355]	training's binary_logloss: 4.40551e-05	valid_1's binary_logloss: 0.00515914
# [356]	training's binary_logloss: 4.36997e-05	valid_1's binary_logloss: 0.00515799
# [357]	training's binary_logloss: 4.31282e-05	valid_1's binary_logloss: 0.00516497
# [358]	training's binary_logloss: 4.24745e-05	valid_1's binary_logloss: 0.00516525
# [359]	training's binary_logloss: 4.18759e-05	valid_1's binary_logloss: 0.00515792
# [360]	training's binary_logloss: 4.1382e-05	valid_1's binary_logloss: 0.00516696
# [361]	training's binary_logloss: 4.09882e-05	valid_1's binary_logloss: 0.00516874
# [362]	training's binary_logloss: 4.05941e-05	valid_1's binary_logloss: 0.00516982
# [363]	training's binary_logloss: 3.99212e-05	valid_1's binary_logloss: 0.00517912
# [364]	training's binary_logloss: 3.95376e-05	valid_1's binary_logloss: 0.0051844
# [365]	training's binary_logloss: 3.91258e-05	valid_1's binary_logloss: 0.00518154
# [366]	training's binary_logloss: 3.86881e-05	valid_1's binary_logloss: 0.00518752
# [367]	training's binary_logloss: 3.83397e-05	valid_1's binary_logloss: 0.00519016
# [368]	training's binary_logloss: 3.80441e-05	valid_1's binary_logloss: 0.00519178
# [369]	training's binary_logloss: 3.73696e-05	valid_1's binary_logloss: 0.00518222
# [370]	training's binary_logloss: 3.70124e-05	valid_1's binary_logloss: 0.0051919
# [371]	training's binary_logloss: 3.66641e-05	valid_1's binary_logloss: 0.00519649
# [372]	training's binary_logloss: 3.6022e-05	valid_1's binary_logloss: 0.00519013
# [373]	training's binary_logloss: 3.56835e-05	valid_1's binary_logloss: 0.00519107
# [374]	training's binary_logloss: 3.5282e-05	valid_1's binary_logloss: 0.00519013
# [375]	training's binary_logloss: 3.49469e-05	valid_1's binary_logloss: 0.00519549
# [376]	training's binary_logloss: 3.46672e-05	valid_1's binary_logloss: 0.00519776
# [377]	training's binary_logloss: 3.44515e-05	valid_1's binary_logloss: 0.00519994
# [378]	training's binary_logloss: 3.42185e-05	valid_1's binary_logloss: 0.00520619
# [379]	training's binary_logloss: 3.39996e-05	valid_1's binary_logloss: 0.00520287
# [380]	training's binary_logloss: 3.34477e-05	valid_1's binary_logloss: 0.00519965
# [381]	training's binary_logloss: 3.31805e-05	valid_1's binary_logloss: 0.00520081
# [382]	training's binary_logloss: 3.25914e-05	valid_1's binary_logloss: 0.00519463
# [383]	training's binary_logloss: 3.23563e-05	valid_1's binary_logloss: 0.00519931
# [384]	training's binary_logloss: 3.19888e-05	valid_1's binary_logloss: 0.00519976
# [385]	training's binary_logloss: 3.17065e-05	valid_1's binary_logloss: 0.00519978
# [386]	training's binary_logloss: 3.14589e-05	valid_1's binary_logloss: 0.00520126
# [387]	training's binary_logloss: 3.1051e-05	valid_1's binary_logloss: 0.00519939
# [388]	training's binary_logloss: 3.08257e-05	valid_1's binary_logloss: 0.00520564
# [389]	training's binary_logloss: 3.03246e-05	valid_1's binary_logloss: 0.00519302
# [390]	training's binary_logloss: 3.01156e-05	valid_1's binary_logloss: 0.00519952
# [391]	training's binary_logloss: 2.98245e-05	valid_1's binary_logloss: 0.0051992
# [392]	training's binary_logloss: 2.96209e-05	valid_1's binary_logloss: 0.00520733
# [393]	training's binary_logloss: 2.90731e-05	valid_1's binary_logloss: 0.00519513
# [394]	training's binary_logloss: 2.88575e-05	valid_1's binary_logloss: 0.00520422
# [395]	training's binary_logloss: 2.86628e-05	valid_1's binary_logloss: 0.0052115
# [396]	training's binary_logloss: 2.83717e-05	valid_1's binary_logloss: 0.00521093
# [397]	training's binary_logloss: 2.81985e-05	valid_1's binary_logloss: 0.00521797
# [398]	training's binary_logloss: 2.76288e-05	valid_1's binary_logloss: 0.00521204
# [399]	training's binary_logloss: 2.73935e-05	valid_1's binary_logloss: 0.00521297
# [400]	training's binary_logloss: 2.70404e-05	valid_1's binary_logloss: 0.00521126
# [401]	training's binary_logloss: 2.67671e-05	valid_1's binary_logloss: 0.00521025
# [402]	training's binary_logloss: 2.64622e-05	valid_1's binary_logloss: 0.00521694
# [403]	training's binary_logloss: 2.63091e-05	valid_1's binary_logloss: 0.00522255
# [404]	training's binary_logloss: 2.61029e-05	valid_1's binary_logloss: 0.00522236
# [405]	training's binary_logloss: 2.59431e-05	valid_1's binary_logloss: 0.00522188
# [406]	training's binary_logloss: 2.55012e-05	valid_1's binary_logloss: 0.00521884
# [407]	training's binary_logloss: 2.52395e-05	valid_1's binary_logloss: 0.00522725
# [408]	training's binary_logloss: 2.50198e-05	valid_1's binary_logloss: 0.00523085
# [409]	training's binary_logloss: 2.47982e-05	valid_1's binary_logloss: 0.00523278
# [410]	training's binary_logloss: 2.45947e-05	valid_1's binary_logloss: 0.00523076
# [411]	training's binary_logloss: 2.43853e-05	valid_1's binary_logloss: 0.00523008
# [412]	training's binary_logloss: 2.39292e-05	valid_1's binary_logloss: 0.00522202
# [413]	training's binary_logloss: 2.3505e-05	valid_1's binary_logloss: 0.00521347
# [414]	training's binary_logloss: 2.331e-05	valid_1's binary_logloss: 0.00521526
# [415]	training's binary_logloss: 2.3127e-05	valid_1's binary_logloss: 0.00522157
# [416]	training's binary_logloss: 2.29525e-05	valid_1's binary_logloss: 0.00522329
# [417]	training's binary_logloss: 2.2703e-05	valid_1's binary_logloss: 0.00522051
# [418]	training's binary_logloss: 2.2502e-05	valid_1's binary_logloss: 0.00522253
# [419]	training's binary_logloss: 2.2326e-05	valid_1's binary_logloss: 0.00522346
# [420]	training's binary_logloss: 2.20772e-05	valid_1's binary_logloss: 0.00522078
# [421]	training's binary_logloss: 2.19005e-05	valid_1's binary_logloss: 0.00522071
# [422]	training's binary_logloss: 2.17164e-05	valid_1's binary_logloss: 0.00522033
# [423]	training's binary_logloss: 2.15377e-05	valid_1's binary_logloss: 0.00522084
# [424]	training's binary_logloss: 2.13958e-05	valid_1's binary_logloss: 0.00522227
# [425]	training's binary_logloss: 2.12441e-05	valid_1's binary_logloss: 0.00522553
# [426]	training's binary_logloss: 2.09744e-05	valid_1's binary_logloss: 0.00522543
# [427]	training's binary_logloss: 2.08088e-05	valid_1's binary_logloss: 0.00523168
# [428]	training's binary_logloss: 2.05853e-05	valid_1's binary_logloss: 0.00522873
# [429]	training's binary_logloss: 2.04291e-05	valid_1's binary_logloss: 0.00523548
# [430]	training's binary_logloss: 2.02181e-05	valid_1's binary_logloss: 0.005243
# [431]	training's binary_logloss: 2.00203e-05	valid_1's binary_logloss: 0.00524823
# [432]	training's binary_logloss: 1.98671e-05	valid_1's binary_logloss: 0.00524693
# [433]	training's binary_logloss: 1.97171e-05	valid_1's binary_logloss: 0.00525143
# [434]	training's binary_logloss: 1.9601e-05	valid_1's binary_logloss: 0.00525429
# [435]	training's binary_logloss: 1.9371e-05	valid_1's binary_logloss: 0.00525057
# [436]	training's binary_logloss: 1.92309e-05	valid_1's binary_logloss: 0.00525588
# [437]	training's binary_logloss: 1.90705e-05	valid_1's binary_logloss: 0.00525205
# [438]	training's binary_logloss: 1.88504e-05	valid_1's binary_logloss: 0.00524743
# [439]	training's binary_logloss: 1.85994e-05	valid_1's binary_logloss: 0.00524167
# [440]	training's binary_logloss: 1.84432e-05	valid_1's binary_logloss: 0.00524718
# [441]	training's binary_logloss: 1.83312e-05	valid_1's binary_logloss: 0.00524977
# [442]	training's binary_logloss: 1.82044e-05	valid_1's binary_logloss: 0.00525147
# [443]	training's binary_logloss: 1.79798e-05	valid_1's binary_logloss: 0.00524639
# [444]	training's binary_logloss: 1.78727e-05	valid_1's binary_logloss: 0.00525298
# [445]	training's binary_logloss: 1.77451e-05	valid_1's binary_logloss: 0.00525342
# [446]	training's binary_logloss: 1.76435e-05	valid_1's binary_logloss: 0.00525477
# [447]	training's binary_logloss: 1.75223e-05	valid_1's binary_logloss: 0.00525461
# [448]	training's binary_logloss: 1.74049e-05	valid_1's binary_logloss: 0.0052552
# [449]	training's binary_logloss: 1.72673e-05	valid_1's binary_logloss: 0.00525272
# [450]	training's binary_logloss: 1.71456e-05	valid_1's binary_logloss: 0.00525931
# [451]	training's binary_logloss: 1.70516e-05	valid_1's binary_logloss: 0.0052653
# [452]	training's binary_logloss: 1.69136e-05	valid_1's binary_logloss: 0.00526344
# [453]	training's binary_logloss: 1.68033e-05	valid_1's binary_logloss: 0.00527259
# [454]	training's binary_logloss: 1.65672e-05	valid_1's binary_logloss: 0.00526507
# [455]	training's binary_logloss: 1.64672e-05	valid_1's binary_logloss: 0.00526735
# [456]	training's binary_logloss: 1.62912e-05	valid_1's binary_logloss: 0.00526668
# [457]	training's binary_logloss: 1.6142e-05	valid_1's binary_logloss: 0.00526398
# [458]	training's binary_logloss: 1.60373e-05	valid_1's binary_logloss: 0.00526683
# [459]	training's binary_logloss: 1.59159e-05	valid_1's binary_logloss: 0.00527179
# [460]	training's binary_logloss: 1.57581e-05	valid_1's binary_logloss: 0.0052666
# [461]	training's binary_logloss: 1.56638e-05	valid_1's binary_logloss: 0.00527332
# [462]	training's binary_logloss: 1.55692e-05	valid_1's binary_logloss: 0.00527318
# [463]	training's binary_logloss: 1.54674e-05	valid_1's binary_logloss: 0.00527039
# [464]	training's binary_logloss: 1.53689e-05	valid_1's binary_logloss: 0.00527113
# [465]	training's binary_logloss: 1.52625e-05	valid_1's binary_logloss: 0.0052692
# [466]	training's binary_logloss: 1.51648e-05	valid_1's binary_logloss: 0.00527105
# [467]	training's binary_logloss: 1.50386e-05	valid_1's binary_logloss: 0.00527135
# [468]	training's binary_logloss: 1.4932e-05	valid_1's binary_logloss: 0.00527109
# [469]	training's binary_logloss: 1.487e-05	valid_1's binary_logloss: 0.00527522
# [470]	training's binary_logloss: 1.46689e-05	valid_1's binary_logloss: 0.00526894
# [471]	training's binary_logloss: 1.45886e-05	valid_1's binary_logloss: 0.0052748
# [472]	training's binary_logloss: 1.45097e-05	valid_1's binary_logloss: 0.00527562
# [473]	training's binary_logloss: 1.43858e-05	valid_1's binary_logloss: 0.00528003
# [474]	training's binary_logloss: 1.42575e-05	valid_1's binary_logloss: 0.0052754
# [475]	training's binary_logloss: 1.41604e-05	valid_1's binary_logloss: 0.00527494
# [476]	training's binary_logloss: 1.40966e-05	valid_1's binary_logloss: 0.00527916
# [477]	training's binary_logloss: 1.39856e-05	valid_1's binary_logloss: 0.00527878
# [478]	training's binary_logloss: 1.38994e-05	valid_1's binary_logloss: 0.00528443
# [479]	training's binary_logloss: 1.3814e-05	valid_1's binary_logloss: 0.00528387
# [480]	training's binary_logloss: 1.37454e-05	valid_1's binary_logloss: 0.00528911
# [481]	training's binary_logloss: 1.36647e-05	valid_1's binary_logloss: 0.00529275
# [482]	training's binary_logloss: 1.35128e-05	valid_1's binary_logloss: 0.00528576
# [483]	training's binary_logloss: 1.34412e-05	valid_1's binary_logloss: 0.00528402
# Early stopping, best iteration is:
# [283]	training's binary_logloss: 0.000130204	valid_1's binary_logloss: 0.00510718
# LGBMClassifier(max_depth=14, n_estimators=8000, num_leaves=1024, random_state=0,
#                reg_lambda=0.1)

# %%
val_pred = lgb.predict(x_val)
test_pred = lgb.predict(test)

# %%
print("Val F1-score: ", f1_score(y_val, val_pred))
print("Test F1-score: ", f1_score(target, test_pred))
# Out:
# Val F1-score:  0.880107768298159
# Test F1-score:  0.7438108484005563

# %%
xgb = XGBClassifier(n_estimators = 10, learning_rate = 0.1, random_state = 0, n_jobs = -1)
xgb.fit(x_train, y_train, early_stopping_rounds = 200, eval_set = [(x_train, y_train), (x_val, y_val)],
       verbose = True)
# Out:
# /usr/local/lib/python3.8/dist-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [13:41:32] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.62402	validation_1-logloss:0.62294
# [1]	validation_0-logloss:0.56720	validation_1-logloss:0.56562
# [2]	validation_0-logloss:0.51934	validation_1-logloss:0.51702
# [3]	validation_0-logloss:0.47754	validation_1-logloss:0.47389
# [4]	validation_0-logloss:0.44439	validation_1-logloss:0.43928
# [5]	validation_0-logloss:0.41470	validation_1-logloss:0.40815
# [6]	validation_0-logloss:0.38925	validation_1-logloss:0.38131
# [7]	validation_0-logloss:0.36716	validation_1-logloss:0.35759
# [8]	validation_0-logloss:0.34791	validation_1-logloss:0.33739
# [9]	validation_0-logloss:0.32844	validation_1-logloss:0.31652
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.1, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=10, n_jobs=-1, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
val_pred = xgb.predict(x_val)
test_pred = xgb.predict(test)

# %%
print("Val F1-score: ", f1_score(y_val, val_pred))
print("Test F1-score: ", f1_score(target, test_pred))
# Out:
# Val F1-score:  0.24704507078841406
# Test F1-score:  0.1936606317620834

# %% [markdown]
# #### Building a Stratified K-Fold model

# %%
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 0)

splits = kfold.split(X, y)

val_acc_scores = []
val_weighted_scores = []

test_acc_scores = []
test_weighted_scores = []

# %%
for i, (Train, Test) in enumerate(splits):
    X_Train, X_Val, Y_Train, Y_Val = X.iloc[Train], X.iloc[Test], y.iloc[Train], y.iloc[Test]
    
    sm = SMOTE(random_state = 0, n_jobs = -1)
    X_Train, Y_Train = sm.fit_resample(X_Train, Y_Train)
    
    lgb = LGBMClassifier(n_estimators = 8000, learning_rate = 0.1, max_depth = 14, num_leaves = 1024,
                     random_state = 0, n_jobs = -1, reg_lambda = 0.1)
    lgb.fit(X_Train, Y_Train, early_stopping_rounds = 100, eval_set = [(X_Train, Y_Train), (X_Val, Y_Val)],  verbose = False)
    
    with open('Model_Data/model_'+str(i+1)+'.pkl', 'wb') as f:
        pickle.dump(lgb, f)
    print('Model-' + str(i+1)+ ' done')
    
    val_pred = lgb.predict(X_Val)
    
    val_acc_scores.append(accuracy_score(Y_Val, val_pred))
    val_weighted_scores.append(f1_score(Y_Val, val_pred))
    
    test_pred = lgb.predict(test)
    
    test_acc_scores.append(accuracy_score(target, test_pred))
    test_weighted_scores.append(f1_score(target, test_pred))
# Out:
# Model-1 done
# Model-2 done
# Model-3 done
# Model-4 done
# Model-5 done

# %%
print("Validation Weighted F1:", sum(val_weighted_scores)/len(val_weighted_scores))
print("Validation Accuracy:", sum(val_acc_scores)/len(val_acc_scores))

print("Test Weighted F1:", sum(test_weighted_scores)/len(test_weighted_scores))
print("Test Accuracy:", sum(test_acc_scores)/len(test_acc_scores))
# Out:
# Validation Weighted F1: 0.8814541027194241
# Validation Accuracy: 0.9986519366842115
# Test Weighted F1: 0.739397502481668
# Test Accuracy: 0.9983203741459263
